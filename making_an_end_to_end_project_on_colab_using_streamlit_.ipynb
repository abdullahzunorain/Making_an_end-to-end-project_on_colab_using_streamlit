# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullahzunorain/Making_an_end-to-end-project_on_colab_using_streamlit/blob/main/making_an_end_to_end_project_on_colab_using_streamlit_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit

# %%
# !wget -q -O - ipv4.icanhazip.com

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# make a `.py(app.py)` file as shown in the screenshots at the top and run it using below commands
# !streamlit run app.py & npx localtunnel --port 8501

# %% [markdown]
# ![image.png](data:image/png;base64,...)
